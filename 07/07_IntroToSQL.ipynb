# %%
from sqlalchemy import *
import pandas as pd
engine = create_engine('postgresql://student_ies:PythonData@localhost:5432/student_ies')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# # Lecture 7 - Intro to databases
#
# ### Contents:
# * Databases
# * DataTypes
# * Tables
# * Schema
# * Joins
# * Python - SQLAlchemy
# * Pandas implementation!

# %% [markdown]
# ## Relational databases
#
# * huge data
# * simultanous access and changes of it
# * read it very fast
# * Raw data
# * Combine various sources of data
# * manage access to data
# * include inside business processes
# * Many different applications!
#     * Business
#     * Web-servers
#     * Big data
#
# ## SQL
# *Structured Query Language*
# * Human readable
# * Different implementations
#     * SQLite, MySQL, Oracle, PostgreSQL
# * SQL is only a language
# * Data are stored in *Tables*
# * Connected via *Relations*
# * NoSQL
# * Allow for limited aggregation, filtering and analysis
#
# ## How to use it?
# * Command-line
# * Programming interface
# * GUI Interface - [DBeaver](https://dbeaver.io/)
# * Integration with existing software - MS Office, GIS, etc
#
# ### Data Layers
# * Value < Rows < Tables < Schemas < Databases < Database servers
#
# ### Data Types
# depends on specific application
# * numeric
#     * INT, INTEGER, REAL, FLOAT, DOUBLE etc.
# * strings
#     * STRING, TEXT, VARCHAR
# * more specialized
#     * DATE, TIME etc.

# %% [markdown]
# ### IES database
# The data from past lecture are stored in three tables:
#
# *people*, *courses* and *theses*
#
# Try to explore:

# %%
pd.read_sql_query(
'''
SELECT * FROM people
''',con=engine).columns
# Out:
# Index(['id', 'name', 'position', 'field_of_interest', 'membership', 'office',
#        'email', 'phone', 'available', 'organisation_memberships', 'education',
#        'job_history', 'extra_activities', 'bachelor_theses', 'master_theses',
#        'researcher', 'category', 'bachelor_all', 'bachelor_awarded',
#        'master_all', 'master_awarded'],
#       dtype='object')

# %% [markdown]
# ### SELECT statement
#
# I want to know all the most succesful teachers on IES in terms of theses (bachelor and masters) supervision

# %%
SELECT id,
    (master_awarded + bachelor_awarded) AS awarded,
    (master_all + bachelor_all) AS all,
    (master_awarded + bachelor_awarded)/(master_all + bachelor_all) AS award_share  
FROM people
WHERE (master_awarded + bachelor_awarded)/(master_all + bachelor_all) != 'NaN'
ORDER BY award_share DESC
LIMIT 10

# %%
pd.read_sql_query(
'''
SELECT id,name,
    (bachelor_awarded + master_awarded)/(bachelor_all + master_all) as share_awarded
FROM people
ORDER BY share_awarded DESC
LIMIT 10
''',con=engine)
# Out:
#              id  name  share_awarded
# 0         fencl  None            NaN
# 1    dolezalova  None            NaN
# 2       kopecna  None            NaN
# 3      smidkova   NaN            NaN
# 4     micuchova  None            NaN
# 5         fcech  None            NaN
# 6  schnellerova  None            NaN
# 7       komarek  None            NaN
# 8        nevrla  None            NaN
# 9       firtova  None            NaN

# %% [markdown]
# What is missing?
#
# ### Relations!
#
# see other two tables:
#
# *people_courses* and *people_theses*

# %%
pd.read_sql_query(
'''
SELECT * FROM people_courses
''',con=engine).head()
# Out:
#   people-id  courses-id
# 0   barunik      JEM005
# 1   barunik  JED412,413
# 2   vosvrda  JED412,413
# 3   barunik      JEM059
# 4     vacha      JEM059

# %% [markdown]
# ### JOINS
#
# * connecting tables - relations!
#
#
#
# <img src='https://www.dofactory.com/Images/sql-joins.png'/>

# %% [markdown]
# ### Inner
# * most common - give me the match!
# * when you see match, keep it, otherwise drop it.

# %%
pd.read_sql_query(
'''
SELECT c.name,p.researcher FROM courses c
INNER JOIN people_courses pc ON c.id = pc."courses-id" 
INNER JOIN people p ON p.id = pc."people-id"
''',con=engine).head()
# Out:
#                                                 name  \
# 0                     JEM005 - Advanced Econometrics
# 1  JED412,413 - Nonlinear Dynamic Economic System...
# 2  JED412,413 - Nonlinear Dynamic Economic System...
# 3                    JEM059 - Quantitative Finance I
# 4                    JEM059 - Quantitative Finance I
#
#                          researcher
# 0    doc. PhDr. Jozef Baruník Ph.D.
# 1    doc. PhDr. Jozef Baruník Ph.D.
# 2  prof. Ing. Miloslav Vošvrda CSc.
# 3    doc. PhDr. Jozef Baruník Ph.D.
# 4            Mgr. Lukáš Vácha Ph.D.

# %% [markdown]
# ### Left
# INNER + rows from LEFT with no match in the RIGHT

# %%
pd.read_sql_query(
'''
SELECT * FROM courses c
LEFT JOIN people_courses pc ON c.id = pc."courses-id"
''',con=engine).head()

# %% [markdown]
# ### Right
# INNER + rows from RIGHT with no match in the LEFT

# %%
pd.read_sql_query(
'''
SELECT * FROM courses c
RIGHT JOIN people_courses pc ON c.id = pc."courses-id"
''',con=engine).head()

# %% [markdown]
# ### FULL
# INNER + rows from both LEFT and RIGHT with no match in other table

# %%
pd.read_sql_query(
'''
SELECT * FROM courses c
FULL JOIN people_courses pc ON c.id = pc."courses-id"
''',con=engine).head()

# %% [markdown]
# ### MULTIPLE JOINS

# %%
pd.read_sql_query('''
SELECT p.researcher,c.name FROM people p
INNER JOIN people_courses pc ON p.id = pc."people-id"
INNER JOIN courses c ON pc."courses-id" = c.id
''',con=engine).head()

# %% [markdown]
# ## CREATE TABLE
#
# jump to DBeaver
#
# explore *courses*, *theses* and *people*

# %% [markdown]
# ## Integration to Pandas
# * using SQLAlchemy
# * Compatible across databases
# * beyond the scope of this lecture
#
# BUT!
# ### Connection Strings:
# ` create_engine('postgresql://student_ies:PythonData@localhost:5432/student_ies')`
#
# or
#
# ` create_engine('sqlite:///sqlite.db')`
#
# ### pd.read_sql_query

# %%
conn = create_engine('postgresql://student_ies:PythonData@localhost:5432/student_ies')
pd.read_sql_table('people',con=conn).head()
# Out:
#             id  name                           position  \
# 0      barunik  None                Associate Professor
# 1       bauerm  None                Associate Professor
# 2  baxajaromir  None                Assistant Professor
# 3     antosova  None  Adjunct Lecturer, Research Fellow
# 4       cahlik  None                Associate Professor
#
#                                    field_of_interest  \
# 0        Financial Economics, Financial Econometrics
# 1  Development Economics, Behavioral Economics, E...
# 2            Macroeconomics, Institutional Economics
# 3                    Health Economics, Health Policy
# 4  Macroeconomics, Economic Development and Growt...
#
#                                           membership office  \
# 0          Internal, Macroeconomics and Econometrics    503
# 1                  Institutional Economics, Internal    402
# 2          Internal, Macroeconomics and Econometrics    311
# 3  European Economic Integration and Economic Pol...
# 4          Internal, Macroeconomics and Econometrics    410
#
#                                              email            phone  \
# 0             barunik [AT] fsv [DOT] cuni [DOT] cz  +420(776)259273
# 1              bauerm [AT] fsv [DOT] cuni [DOT] cz      222 112 329
# 2  jaromir [DOT] baxa [AT] fsv [DOT] cuni [DOT] cz      222 112 309
# 3       lucie [DOT] bryndova [AT] centrum [DOT] cz
# 4              cahlik [AT] fsv [DOT] cuni [DOT] cz      222 112 318
#
#                                available  \
# 0                           upon request
# 1                           Tue 11-12.30
# 2                         by appointment
# 3           based on agreement via email
# 4  Thursday 4.00 - 5.00 pm  Room No. 410
#
#                             organisation_memberships       ...        \
# 0  The Econometric Society, The Society for Finan...       ...
# 1                                               None       ...
# 2                                               None       ...
# 3                                               None       ...
# 4                                               None       ...
#
#                                          job_history  \
# 0  2017 - research visit Humboldt-Universität zu ...
# 1  ACADEMIC AFFILIATIONS\n\r\n2017+ \tCERGE-EI (u...
# 2  2006 - Teaching at the IES FSV UK graduate cou...
# 3  2008 +    JEM101 Health Economics, IES FSV UK\...
# 4  1980-85 Teaching at the University of Economic...
#
#                                     extra_activities  \
# 0  2018+ President of the Czech Econometric Socie...
# 1                                               None
# 2  2012 - Liberec region, member of Regional asse...
# 3                                               None
# 4  2000+   Member of the Czech Economic Society (...
#
#                                      bachelor_theses  \
# 0  I welcome any topic in the field of Applied Fi...
# 1                                               None
# 2  If you wish to write a bachelor thesis with me...
# 3          any topic from the health economics field
# 4                           Please look into the SIS
#
#                                        master_theses  \
# 0  My research interest is in Econometrics of Fin...
# 1  Topics in applied development microeconomics a...
# 2  If you wish to write a diploma thesis with me,...
# 3          any topic from the health economics field
# 4                           Please look into the SIS
#
#                        researcher         category bachelor_all  \
# 0  doc. PhDr. Jozef Baruník Ph.D.  Current faculty          4.0
# 1   doc. PhDr. Michal Bauer Ph.D.  Current faculty          5.0
# 2        PhDr. Jaromír Baxa Ph.D.  Current faculty          8.0
# 3            PhDr. Lucie Bryndová  Current faculty          2.0
# 4     doc. Ing. Tomáš Cahlík CSc.  Current faculty         60.0
#
#    bachelor_awarded  master_all  master_awarded
# 0               0.0        54.0            20.0
# 1               1.0         9.0             5.0
# 2               2.0        38.0             7.0
# 3               1.0         3.0             1.0
# 4               3.0        39.0             8.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### pd.read_sql_table

# %%
df = pd.DataFrame()
# ?df.to_sql
# Out:
# Signature:
# df.to_sql(
#     ['name', 'con', 'schema=None', "if_exists='fail'", 'index=True', 'index_label=None', 'chunksize=None', 'dtype=None'],
# )
# Docstring:
# Write records stored in a DataFrame to a SQL database.
#
# Databases supported by SQLAlchemy [1]_ are supported. Tables can be
# newly created, appended to, or overwritten.
#
# Parameters
# ----------
# name : string
#     Name of SQL table.
# con : sqlalchemy.engine.Engine or sqlite3.Connection
#     Using SQLAlchemy makes it possible to use any DB supported by that
#     library. Legacy support is provided for sqlite3.Connection objects.
# schema : string, optional
#     Specify the schema (if database flavor supports this). If None, use
#     default schema.
# if_exists : {'fail', 'replace', 'append'}, default 'fail'
#     How to behave if the table already exists.
#
#     * fail: Raise a ValueError.
#     * replace: Drop the table before inserting new values.
#     * append: Insert new values to the existing table.
#
# index : boolean, default True
#     Write DataFrame index as a column. Uses `index_label` as the column
#     name in the table.
# index_label : string or sequence, default None
#     Column label for index column(s). If None is given (default) and
#     `index` is True, then the index names are used.
#     A sequence should be given if the DataFrame uses MultiIndex.
# chunksize : int, optional
#     Rows will be written in batches of this size at a time. By default,
#     all rows will be written at once.
# dtype : dict, optional
#     Specifying the datatype for columns. The keys should be the column
#     names and the values should be the SQLAlchemy types or strings for
#     the sqlite3 legacy mode.
#
# Raises
# ------
# ValueError
#     When the table already exists and `if_exists` is 'fail' (the
#     default).
#
# See Also
# --------
# pandas.read_sql : read a DataFrame from a table
#
# References
# ----------
# .. [1] http://docs.sqlalchemy.org
# .. [2] https://www.python.org/dev/peps/pep-0249/
#
# Examples
# --------
#
# Create an in-memory SQLite database.
#
# >>> from sqlalchemy import create_engine
# >>> engine = create_engine('sqlite://', echo=False)
#
# Create a table from scratch with 3 rows.
#
# >>> df = pd.DataFrame({'name' : ['User 1', 'User 2', 'User 3']})
# >>> df
#      name
# 0  User 1
# 1  User 2
# 2  User 3
#
# >>> df.to_sql('users', con=engine)
# >>> engine.execute("SELECT * FROM users").fetchall()
# [(0, 'User 1'), (1, 'User 2'), (2, 'User 3')]
#
# >>> df1 = pd.DataFrame({'name' : ['User 4', 'User 5']})
# >>> df1.to_sql('users', con=engine, if_exists='append')
# >>> engine.execute("SELECT * FROM users").fetchall()
# [(0, 'User 1'), (1, 'User 2'), (2, 'User 3'),
#  (0, 'User 4'), (1, 'User 5')]
#
# Overwrite the table with just ``df1``.
#
# >>> df1.to_sql('users', con=engine, if_exists='replace',
# ...            index_label='id')
# >>> engine.execute("SELECT * FROM users").fetchall()
# [(0, 'User 4'), (1, 'User 5')]
#
# Specify the dtype (especially useful for integers with missing values).
# Notice that while pandas is forced to store the data as floating point,
# the database supports nullable integers. When fetching the data with
# Python, we get back integer scalars.
#
# >>> df = pd.DataFrame({"A": [1, None, 2]})
# >>> df
#      A
# 0  1.0
# 1  NaN
# 2  2.0
#
# >>> from sqlalchemy.types import Integer
# >>> df.to_sql('integers', con=engine, index=False,
# ...           dtype={"A": Integer()})
#
# >>> engine.execute("SELECT * FROM integers").fetchall()
# [(1,), (None,), (2,)]
# File:      /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py
# Type:      method

# %%
awarded = pd.read_sql_query(
'''
SELECT id,
    (master_awarded + bachelor_awarded) AS awarded,
    (master_all + bachelor_all) AS all,
    (master_awarded + bachelor_awarded)/(master_all + bachelor_all) AS award_share  
FROM people
WHERE (master_awarded + bachelor_awarded)/(master_all + bachelor_all) != 'NaN'
ORDER BY award_share DESC
''',con=engine)

# %%
from bokeh.models import ColumnDataSource
from bokeh.io import show, output_file,output_notebook
from bokeh.plotting import figure

output_file('index.html')
source = ColumnDataSource(data = {col:awarded[col][:10] for col in awarded.columns})

TOOLTIPS = [
    ("id", "$id"),
    ("awarded theses", "$awarded"),
    ("all theses",'$all')

]


p = figure(x_range=awarded.id[:10], plot_height=250, title="Best people (by share of awarded theses)",tooltips=TOOLTIPS)

p.vbar(x='id', top='award_share', width=0.9,source=source)

p.xgrid.grid_line_color = None

show(p)
