# %%
import requests
import pandas as pd
import time

# %% [markdown]
# # Seminar - APIs and real-life coding

# %% [markdown]
# ## Task 1: Requesting API
# ### 1a. Create a function requesting data from sreality
#
# ```python
# base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page={}'.format(i)
#
# r = requests.get(base_url)
# d = r.json()
# ```
#
# * function should parametrize:
#     * `category_main_cb` - `{'flat':1, 'house':2, 'land':3 }`
#     * `category_type_cb` - `{'sell':1,'rent':2}`
#     * `locality_region_id` - `{'Praha':10,'Brno':14}`
#     * `page` parameter
# * use string inputs for `category_main_cb` and `category_type_cb`
# * test the validity of inputs
# * include try/except clause to handle errors
# * function should return JSON data in python types
# * do not forget to sleep each request at least 0.5s

# %%
def request_sreality(page, category_main='flat', category_type='sell', locality_region='Praha'):
    
    time.sleep(0.5)

    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1,'rent':2}
    region_mapping = {'Praha':10, 'Brno':14}
    
    if category_main not in category_mains:
        raise Exception(f'Unknown category main {category_main}')
    
    if category_type not in category_types:
        raise Exception(f'Unknown category type {category_type}')
    
    if locality_region not in region_mapping:
        raise Exception(f'Unknown locality region {locality_region}')
    
    url_template = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main_cb}&category_type_cb={category_type_cb}&locality_region_id={locality_region_id}&per_page60&page={page}'
    
    try:
        url = url_template.format(
            category_main_cb=category_mains[category_main],
            category_type_cb=category_types[category_type],
            locality_region_id=region_mapping[locality_region],
            page=page
        )

        r = requests.get(url)

        return r.json()
    except Exception as e:
        print(e)
d = request_sreality(0)
d.keys()
# Out:
# dict_keys(['meta_description', 'result_size', '_embedded', 'filterLabels', 'title', 'filter', '_links', 'locality', 'locality_dativ', 'logged_in', 'per_page', 'category_instrumental', 'page', 'filterLabels2'])

# %% [markdown]
# ### 1b. Create a function converting sreality json data into pandas dataframe

# %%
def sreality_json_to_df(sreality_data):
    return pd.DataFrame(sreality_data['_embedded']['estates'])
sreality_json_to_df(d)
# Out:
#                                   labelsReleased  has_panorama  \
# 0                                       [[], []]             0
# 1    [[after_reconstruction, loggia, panel], []]             0
# 2                 [[panel], [shop, post_office]]             0
# 3                                       [[], []]             0
# 4                            [[], [metro, shop]]             0
# 5                                       [[], []]             0
# 6                             [[collective], []]             0
# 7                                       [[], []]             0
# 8                                       [[], []]             0
# 9                                       [[], []]             0
# 10           [[partly_furnished], [post_office]]             0
# 11                                      [[], []]             0
# 12                  [[after_reconstruction], []]             0
# 13         [[loggia, partly_furnished], [metro]]             0
# 14           [[partly_furnished], [post_office]]             0
# 15                      [[partly_furnished], []]             0
# 16                                [[loggia], []]             0
# 17                           [[], [metro, shop]]             0
# 18  [[collective, not_furnished], [metro, shop]]             0
# 19              [[loggia, partly_furnished], []]             0
# 20   [[after_reconstruction, not_furnished], []]             0
#
#                                                labels  is_auction  \
# 0                                                  []       False
# 1                 [Po rekonstrukci, Lodžie, Panelová]       False
# 2   [Panelová, Obchod 5 min. pěšky, Pošta 2 min. p...       False
# 3                                                  []       False
# 4           [Metro 2 min. pěšky, Obchod 3 min. pěšky]       False
# 5                                                  []       False
# 6                                        [Družstevní]       False
# 7                                                  []       False
# 8                                                  []       False
# 9                                                  []       False
# 10            [Částečně vybavený, Pošta 6 min. pěšky]       False
# 11                                                 []       False
# 12                                  [Po rekonstrukci]       False
# 13    [Lodžie, Částečně vybavený, Metro 4 min. pěšky]       False
# 14            [Částečně vybavený, Pošta 7 min. pěšky]       False
# 15                                [Částečně vybavený]       False
# 16                                           [Lodžie]       False
# 17          [Metro 2 min. pěšky, Obchod 5 min. pěšky]       False
# 18  [Družstevní, Nevybavený, Metro 1 min. pěšky, O...       False
# 19                        [Lodžie, Částečně vybavený]       False
# 20                      [Po rekonstrukci, Nevybavený]       False
#
#                                             labelsAll  \
# 0   [[new_building, personal, balcony, terrace, ce...
# 1   [[personal, after_reconstruction, loggia, pane...
# 2   [[personal, panel, furnished], [playground, sm...
# 3   [[new_building, personal, terrace, brick, cell...
# 4   [[personal, balcony, brick], [candy_shop, vet,...
# 5   [[new_building, personal, elevator, garage], [...
# 6   [[new_building, collective, balcony, brick, pa...
# 7   [[new_building, personal, terrace, brick, park...
# 8   [[new_building, personal, balcony, brick, elev...
# 9   [[personal, balcony, terrace, brick, cellar, e...
# 10  [[personal, brick, cellar, partly_furnished], ...
# 11  [[personal, brick, elevator], [playground, nat...
# 12  [[personal, after_reconstruction, brick, cella...
# 13  [[personal, loggia, brick, cellar, elevator, p...
# 14  [[personal, brick, partly_furnished], [playgro...
# 15  [[personal, cellar, elevator, partly_furnished...
# 16  [[new_building, personal, balcony, loggia, ter...
# 17  [[personal, terrace, brick, cellar, elevator],...
# 18  [[collective, terrace, brick, not_furnished], ...
# 19  [[personal, loggia, cellar, elevator, garage, ...
# 20  [[personal, after_reconstruction, cellar, elev...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 1   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  1
# 2   {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 3   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 4   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 5   {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 6   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 7   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 8   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 9   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 10  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 11  {'category_main_cb': 1, 'category_sub_cb': 16,...                  0
# 12  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 13  {'category_main_cb': 1, 'category_sub_cb': 5, ...                  1
# 14  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 15  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 16  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 17  {'category_main_cb': 1, 'category_sub_cb': 11,...                  0
# 18  {'category_main_cb': 1, 'category_sub_cb': 9, ...                  1
# 19  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 20  {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
#
#     category  has_floor_plan  \
# 0          1               1
# 1          1               0
# 2          1               0
# 3          1               0
# 4          1               1
# 5          1               1
# 6          1               1
# 7          1               0
# 8          1               0
# 9          1               0
# 10         1               0
# 11         1               0
# 12         1               0
# 13         1               1
# 14         1               1
# 15         1               1
# 16         1               0
# 17         1               0
# 18         1               0
# 19         1               0
# 20         1               1
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...  2485658700
# 1   {'favourite': {'is_favourite': False, '_links'...  ...    37303372
# 2   {'favourite': {'is_favourite': False, '_links'...  ...  2556937292
# 3   {'favourite': {'is_favourite': False, '_links'...  ...  3499653212
# 4   {'favourite': {'is_favourite': False, '_links'...  ...  1991259212
# 5   {'favourite': {'is_favourite': False, '_links'...  ...  2786600012
# 6   {'favourite': {'is_favourite': False, '_links'...  ...   742011980
# 7   {'favourite': {'is_favourite': False, '_links'...  ...  2292900940
# 8   {'favourite': {'is_favourite': False, '_links'...  ...  2077946956
# 9   {'favourite': {'is_favourite': False, '_links'...  ...  2550781004
# 10  {'favourite': {'is_favourite': False, '_links'...  ...  3751355468
# 11  {'favourite': {'is_favourite': False, '_links'...  ...  3930015564
# 12  {'favourite': {'is_favourite': False, '_links'...  ...  1991025740
# 13  {'favourite': {'is_favourite': False, '_links'...  ...   325698636
# 14  {'favourite': {'is_favourite': False, '_links'...  ...  2800673868
# 15  {'favourite': {'is_favourite': False, '_links'...  ...  3508303436
# 16  {'favourite': {'is_favourite': False, '_links'...  ...  2507457612
# 17  {'favourite': {'is_favourite': False, '_links'...  ...  1684091980
# 18  {'favourite': {'is_favourite': False, '_links'...  ...   102590028
# 19  {'favourite': {'is_favourite': False, '_links'...  ...  1289696332
# 20  {'favourite': {'is_favourite': False, '_links'...  ...  4190504524
#
#    attractive_offer     price  \
# 0                 0  22928000
# 1                 0   9660000
# 2                 0   3856000
# 3                 0   8757000
# 4                 0  11930000
# 5                 0  13284000
# 6                 0   8926000
# 7                 0  16057000
# 8                 0  12381000
# 9                 0         0
# 10                0  12768000
# 11                0  18701000
# 12                0  20507000
# 13                0   7080000
# 14                0   7080000
# 15                0   6384000
# 16                0  12892000
# 17                0  32179000
# 18                0  30825000
# 19                0  11994000
# 20                0   9531000
#
#                                             price_czk  \
# 0   {'value_raw': 22928000, 'unit': '', 'name': 'C...
# 1   {'value_raw': 9660000, 'unit': '', 'name': 'Ce...
# 2   {'value_raw': 3856000, 'unit': '', 'name': 'Ce...
# 3   {'value_raw': 8757000, 'unit': '', 'name': 'Ce...
# 4   {'value_raw': 11930000, 'unit': '', 'name': 'C...
# 5   {'value_raw': 13284000, 'unit': '', 'name': 'C...
# 6   {'value_raw': 8926000, 'unit': '', 'name': 'Ce...
# 7   {'value_raw': 16057000, 'unit': '', 'name': 'C...
# 8   {'value_raw': 12381000, 'unit': '', 'name': 'C...
# 9   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 10  {'value_raw': 12768000, 'unit': '', 'name': 'C...
# 11  {'value_raw': 18701000, 'unit': '', 'name': 'C...
# 12  {'value_raw': 20507000, 'unit': '', 'name': 'C...
# 13  {'value_raw': 7080000, 'unit': '', 'name': 'Ce...
# 14  {'value_raw': 7080000, 'unit': '', 'name': 'Ce...
# 15  {'value_raw': 6384000, 'unit': '', 'name': 'Ce...
# 16  {'value_raw': 12892000, 'unit': '', 'name': 'C...
# 17  {'value_raw': 32179000, 'unit': '', 'name': 'C...
# 18  {'value_raw': 30825000, 'unit': '', 'name': 'C...
# 19  {'value_raw': 11994000, 'unit': '', 'name': 'C...
# 20  {'value_raw': 9531000, 'unit': '', 'name': 'Ce...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 5   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 6   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 7   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 8   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 9   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 10  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 11  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 12  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 13  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 14  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 15  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 16  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 17  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 18  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 19  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...   True
# 20  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                        name  region_tip  \
# 0                   Prodej bytu 3+kk 156 m²     2444145
# 1                     Prodej bytu 3+1 95 m²           0
# 2                    Prodej bytu 1+kk 34 m²           0
# 3                    Prodej bytu 2+kk 59 m²           0
# 4                    Prodej bytu 2+kk 88 m²           0
# 5                    Prodej bytu 3+kk 83 m²           0
# 6                    Prodej bytu 2+kk 74 m²           0
# 7                   Prodej bytu 4+kk 141 m²           0
# 8                    Prodej bytu 2+kk 77 m²           0
# 9         Prodej bytu 4+kk 296 m² (Mezonet)           0
# 10                  Prodej bytu 3+kk 112 m²           0
# 11  Prodej bytu atypické 127 m² (Podkrovní)           0
# 12                  Prodej bytu 4+kk 147 m²           0
# 13                    Prodej bytu 2+1 64 m²           0
# 14                   Prodej bytu 2+kk 61 m²           0
# 15                   Prodej bytu 2+kk 59 m²           0
# 16                   Prodej bytu 3+kk 96 m²           0
# 17         Prodej bytu 5+1 247 m² (Mezonet)           0
# 18                   Prodej bytu 4+1 288 m²           0
# 19                  Prodej bytu 3+kk 112 m²           0
# 20                    Prodej bytu 2+1 74 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 50.0714224276386, 'lon': 14.4594775723...               False
# 1   {'lat': 50.118175427638604, 'lon': 14.49070557...               False
# 2   {'lat': 50.043525427638606, 'lon': 14.51326157...               False
# 3   {'lat': 50.074871427638605, 'lon': 14.49115157...               False
# 4   {'lat': 50.064315427638604, 'lon': 14.47253557...                True
# 5   {'lat': 50.0190654276386, 'lon': 14.3932715723...                True
# 6   {'lat': 50.0777624276386, 'lon': 14.3112545723...               False
# 7   {'lat': 50.1519084276386, 'lon': 14.4968385723...               False
# 8   {'lat': 50.065643427638605, 'lon': 14.50016557...               False
# 9   {'lat': 50.070171427638606, 'lon': 14.45639857...               False
# 10  {'lat': 50.06646742763861, 'lon': 14.467658572...               False
# 11  {'lat': 50.0802454276386, 'lon': 14.4721745723...               False
# 12  {'lat': 50.075569427638605, 'lon': 14.38072357...               False
# 13  {'lat': 50.030456427638605, 'lon': 14.47310857...                True
# 14  {'lat': 50.0591854276386, 'lon': 14.4572775723...                True
# 15  {'lat': 50.096431427638606, 'lon': 14.57054857...               False
# 16  {'lat': 50.025764427638606, 'lon': 14.60684257...               False
# 17  {'lat': 50.062316427638606, 'lon': 14.42753857...               False
# 18  {'lat': 50.061447427638605, 'lon': 14.42788757...               False
# 19  {'lat': 50.0251614276386, 'lon': 14.3434045723...               False
# 20  {'lat': 50.0584254276386, 'lon': 14.4785335723...               False
#
# [21 rows x 27 columns]

# %% [markdown]
# ### 1c. link function `1b` into function `1a`

# %%
def request_sreality(page, category_main='flat', category_type='sell', locality_region='Praha'):
    
    time.sleep(0.5)

    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1,'rent':2}
    region_mapping = {'Praha':10, 'Brno':14}
    
    if category_main not in category_mains:
        raise Exception(f'Unknown category main {category_main}')
    
    if category_type not in category_types:
        raise Exception(f'Unknown category type {category_type}')
    
    if locality_region not in region_mapping:
        raise Exception(f'Unknown locality region {locality_region}')
    
    url_template = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main_cb}&category_type_cb={category_type_cb}&locality_region_id={locality_region_id}&per_page60&page={page}'
    
    try:
        url = url_template.format(
            category_main_cb=category_mains[category_main],
            category_type_cb=category_types[category_type],
            locality_region_id=region_mapping[locality_region],
            page=page
        )

        r = requests.get(url)

        return sreality_json_to_df(r.json())    
    except Exception as e:
        print(e)
d = request_sreality(0)
d.keys()
# Out:
#                                   labelsReleased  has_panorama  \
# 0                                       [[], []]             0
# 1    [[after_reconstruction, loggia, panel], []]             0
# 2                 [[panel], [shop, post_office]]             0
# 3                                       [[], []]             0
# 4                            [[], [metro, shop]]             0
# 5                                       [[], []]             0
# 6                             [[collective], []]             0
# 7                                       [[], []]             0
# 8                                       [[], []]             0
# 9                                       [[], []]             0
# 10           [[partly_furnished], [post_office]]             0
# 11                                      [[], []]             0
# 12                  [[after_reconstruction], []]             0
# 13         [[loggia, partly_furnished], [metro]]             0
# 14           [[partly_furnished], [post_office]]             0
# 15                      [[partly_furnished], []]             0
# 16                                [[loggia], []]             0
# 17                           [[], [metro, shop]]             0
# 18  [[collective, not_furnished], [metro, shop]]             0
# 19              [[loggia, partly_furnished], []]             0
# 20   [[after_reconstruction, not_furnished], []]             0
#
#                                                labels  is_auction  \
# 0                                                  []       False
# 1                 [Po rekonstrukci, Lodžie, Panelová]       False
# 2   [Panelová, Obchod 5 min. pěšky, Pošta 2 min. p...       False
# 3                                                  []       False
# 4           [Metro 2 min. pěšky, Obchod 3 min. pěšky]       False
# 5                                                  []       False
# 6                                        [Družstevní]       False
# 7                                                  []       False
# 8                                                  []       False
# 9                                                  []       False
# 10            [Částečně vybavený, Pošta 6 min. pěšky]       False
# 11                                                 []       False
# 12                                  [Po rekonstrukci]       False
# 13    [Lodžie, Částečně vybavený, Metro 4 min. pěšky]       False
# 14            [Částečně vybavený, Pošta 7 min. pěšky]       False
# 15                                [Částečně vybavený]       False
# 16                                           [Lodžie]       False
# 17          [Metro 2 min. pěšky, Obchod 5 min. pěšky]       False
# 18  [Družstevní, Nevybavený, Metro 1 min. pěšky, O...       False
# 19                        [Lodžie, Částečně vybavený]       False
# 20                      [Po rekonstrukci, Nevybavený]       False
#
#                                             labelsAll  \
# 0   [[personal, balcony, terrace, cellar, elevator...
# 1   [[personal, after_reconstruction, loggia, pane...
# 2   [[personal, panel, furnished], [playground, sm...
# 3   [[new_building, personal, terrace, brick, cell...
# 4   [[personal, balcony, brick], [candy_shop, vet,...
# 5   [[new_building, personal, elevator, garage], [...
# 6   [[new_building, collective, balcony, brick, pa...
# 7   [[new_building, personal, terrace, brick, park...
# 8   [[new_building, personal, balcony, brick, elev...
# 9   [[personal, balcony, terrace, brick, cellar, e...
# 10  [[personal, brick, cellar, partly_furnished], ...
# 11  [[personal, brick, elevator], [playground, nat...
# 12  [[personal, after_reconstruction, brick, cella...
# 13  [[personal, loggia, brick, cellar, elevator, p...
# 14  [[personal, brick, partly_furnished], [playgro...
# 15  [[personal, cellar, elevator, partly_furnished...
# 16  [[new_building, personal, balcony, loggia, ter...
# 17  [[personal, terrace, brick, cellar, elevator],...
# 18  [[collective, terrace, brick, not_furnished], ...
# 19  [[personal, loggia, cellar, elevator, garage, ...
# 20  [[personal, after_reconstruction, cellar, elev...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 1   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  1
# 2   {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 3   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 4   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 5   {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 6   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 7   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 8   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 9   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 10  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 11  {'category_main_cb': 1, 'category_sub_cb': 16,...                  0
# 12  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 13  {'category_main_cb': 1, 'category_sub_cb': 5, ...                  1
# 14  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 15  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 16  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 17  {'category_main_cb': 1, 'category_sub_cb': 11,...                  0
# 18  {'category_main_cb': 1, 'category_sub_cb': 9, ...                  1
# 19  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 20  {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
#
#     category  has_floor_plan  \
# 0          1               1
# 1          1               0
# 2          1               0
# 3          1               0
# 4          1               1
# 5          1               1
# 6          1               1
# 7          1               0
# 8          1               0
# 9          1               0
# 10         1               0
# 11         1               0
# 12         1               0
# 13         1               1
# 14         1               1
# 15         1               1
# 16         1               0
# 17         1               0
# 18         1               0
# 19         1               0
# 20         1               1
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...  2720790348
# 1   {'favourite': {'is_favourite': False, '_links'...  ...    37303372
# 2   {'favourite': {'is_favourite': False, '_links'...  ...  2556937292
# 3   {'favourite': {'is_favourite': False, '_links'...  ...  3499653212
# 4   {'favourite': {'is_favourite': False, '_links'...  ...  1991259212
# 5   {'favourite': {'is_favourite': False, '_links'...  ...  2786600012
# 6   {'favourite': {'is_favourite': False, '_links'...  ...   742011980
# 7   {'favourite': {'is_favourite': False, '_links'...  ...  2292900940
# 8   {'favourite': {'is_favourite': False, '_links'...  ...  2077946956
# 9   {'favourite': {'is_favourite': False, '_links'...  ...  2550781004
# 10  {'favourite': {'is_favourite': False, '_links'...  ...  3751355468
# 11  {'favourite': {'is_favourite': False, '_links'...  ...  3930015564
# 12  {'favourite': {'is_favourite': False, '_links'...  ...  1991025740
# 13  {'favourite': {'is_favourite': False, '_links'...  ...   325698636
# 14  {'favourite': {'is_favourite': False, '_links'...  ...  2800673868
# 15  {'favourite': {'is_favourite': False, '_links'...  ...  3508303436
# 16  {'favourite': {'is_favourite': False, '_links'...  ...  2507457612
# 17  {'favourite': {'is_favourite': False, '_links'...  ...  1684091980
# 18  {'favourite': {'is_favourite': False, '_links'...  ...   102590028
# 19  {'favourite': {'is_favourite': False, '_links'...  ...  1289696332
# 20  {'favourite': {'is_favourite': False, '_links'...  ...  4190504524
#
#    attractive_offer     price  \
# 0                 0  21925000
# 1                 0   9660000
# 2                 0   3856000
# 3                 0   8757000
# 4                 0  11930000
# 5                 0  13284000
# 6                 0   8926000
# 7                 0  16057000
# 8                 0  12381000
# 9                 0         0
# 10                0  12768000
# 11                0  18701000
# 12                0  20507000
# 13                0   7080000
# 14                0   7080000
# 15                0   6384000
# 16                0  12892000
# 17                0  32179000
# 18                0  30825000
# 19                0  11994000
# 20                0   9531000
#
#                                             price_czk  \
# 0   {'value_raw': 21925000, 'unit': '', 'name': 'C...
# 1   {'value_raw': 9660000, 'unit': '', 'name': 'Ce...
# 2   {'value_raw': 3856000, 'unit': '', 'name': 'Ce...
# 3   {'value_raw': 8757000, 'unit': '', 'name': 'Ce...
# 4   {'value_raw': 11930000, 'unit': '', 'name': 'C...
# 5   {'value_raw': 13284000, 'unit': '', 'name': 'C...
# 6   {'value_raw': 8926000, 'unit': '', 'name': 'Ce...
# 7   {'value_raw': 16057000, 'unit': '', 'name': 'C...
# 8   {'value_raw': 12381000, 'unit': '', 'name': 'C...
# 9   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 10  {'value_raw': 12768000, 'unit': '', 'name': 'C...
# 11  {'value_raw': 18701000, 'unit': '', 'name': 'C...
# 12  {'value_raw': 20507000, 'unit': '', 'name': 'C...
# 13  {'value_raw': 7080000, 'unit': '', 'name': 'Ce...
# 14  {'value_raw': 7080000, 'unit': '', 'name': 'Ce...
# 15  {'value_raw': 6384000, 'unit': '', 'name': 'Ce...
# 16  {'value_raw': 12892000, 'unit': '', 'name': 'C...
# 17  {'value_raw': 32179000, 'unit': '', 'name': 'C...
# 18  {'value_raw': 30825000, 'unit': '', 'name': 'C...
# 19  {'value_raw': 11994000, 'unit': '', 'name': 'C...
# 20  {'value_raw': 9531000, 'unit': '', 'name': 'Ce...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 5   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 6   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 7   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 8   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 9   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 10  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 11  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 12  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 13  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 14  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 15  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 16  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 17  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 18  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 19  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...   True
# 20  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                        name  region_tip  \
# 0                   Prodej bytu 4+kk 180 m²     2493152
# 1                     Prodej bytu 3+1 95 m²           0
# 2                    Prodej bytu 1+kk 34 m²           0
# 3                    Prodej bytu 2+kk 59 m²           0
# 4                    Prodej bytu 2+kk 88 m²           0
# 5                    Prodej bytu 3+kk 83 m²           0
# 6                    Prodej bytu 2+kk 74 m²           0
# 7                   Prodej bytu 4+kk 141 m²           0
# 8                    Prodej bytu 2+kk 77 m²           0
# 9         Prodej bytu 4+kk 296 m² (Mezonet)           0
# 10                  Prodej bytu 3+kk 112 m²           0
# 11  Prodej bytu atypické 127 m² (Podkrovní)           0
# 12                  Prodej bytu 4+kk 147 m²           0
# 13                    Prodej bytu 2+1 64 m²           0
# 14                   Prodej bytu 2+kk 61 m²           0
# 15                   Prodej bytu 2+kk 59 m²           0
# 16                   Prodej bytu 3+kk 96 m²           0
# 17         Prodej bytu 5+1 247 m² (Mezonet)           0
# 18                   Prodej bytu 4+1 288 m²           0
# 19                  Prodej bytu 3+kk 112 m²           0
# 20                    Prodej bytu 2+1 74 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 50.1043584276386, 'lon': 14.4615885723...               False
# 1   {'lat': 50.118175427638604, 'lon': 14.49070557...               False
# 2   {'lat': 50.043525427638606, 'lon': 14.51326157...               False
# 3   {'lat': 50.074871427638605, 'lon': 14.49115157...               False
# 4   {'lat': 50.064315427638604, 'lon': 14.47253557...                True
# 5   {'lat': 50.0190654276386, 'lon': 14.3932715723...                True
# 6   {'lat': 50.0777624276386, 'lon': 14.3112545723...               False
# 7   {'lat': 50.1519084276386, 'lon': 14.4968385723...               False
# 8   {'lat': 50.065643427638605, 'lon': 14.50016557...               False
# 9   {'lat': 50.070171427638606, 'lon': 14.45639857...               False
# 10  {'lat': 50.06646742763861, 'lon': 14.467658572...               False
# 11  {'lat': 50.0802454276386, 'lon': 14.4721745723...               False
# 12  {'lat': 50.075569427638605, 'lon': 14.38072357...               False
# 13  {'lat': 50.030456427638605, 'lon': 14.47310857...                True
# 14  {'lat': 50.0591854276386, 'lon': 14.4572775723...                True
# 15  {'lat': 50.096431427638606, 'lon': 14.57054857...               False
# 16  {'lat': 50.025764427638606, 'lon': 14.60684257...               False
# 17  {'lat': 50.062316427638606, 'lon': 14.42753857...               False
# 18  {'lat': 50.061447427638605, 'lon': 14.42788757...               False
# 19  {'lat': 50.0251614276386, 'lon': 14.3434045723...               False
# 20  {'lat': 50.0584254276386, 'lon': 14.4785335723...               False
#
# [21 rows x 27 columns]

# %% [markdown]
# ### 1c. Combining multiple requests into single df
#
# * Function should parametrize:
#     * `start_page` and `end_page`
#     * request parameters
# * construct a list of individual request dfs
# * then feed it into `pd.concat` function

# %%
def multiple_sreality_requests(start_page,end_page,category_main='flat', category_type='sell', locality_region='Praha'):
    return pd.concat([
        request_sreality(i, category_main=category_main, category_type=category_type, locality_region=locality_region) 
        for i in range(start_page,end_page+1)
    ])

raw = multiple_sreality_requests(0,4)
raw.head()
# Out:
#                                 labelsReleased  has_panorama  \
# 0                          [[], [post_office]]             0
# 1  [[after_reconstruction, loggia, panel], []]             0
# 2               [[panel], [shop, post_office]]             0
# 3                                     [[], []]             0
# 4                          [[], [metro, shop]]             0
#
#                                               labels  is_auction  \
# 0                               [Pošta 8 min. pěšky]       False
# 1                [Po rekonstrukci, Lodžie, Panelová]       False
# 2  [Panelová, Obchod 5 min. pěšky, Pošta 2 min. p...       False
# 3                                                 []       False
# 4          [Metro 2 min. pěšky, Obchod 3 min. pěšky]       False
#
#                                            labelsAll  \
# 0  [[new_building, personal, balcony, cellar, ele...
# 1  [[personal, after_reconstruction, loggia, pane...
# 2  [[personal, panel, furnished], [playground, sm...
# 3  [[new_building, personal, terrace, brick, cell...
# 4  [[personal, balcony, brick], [candy_shop, vet,...
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 1  {'category_main_cb': 1, 'category_sub_cb': 7, ...                  1
# 2  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 3  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 4  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
#
#    category  has_floor_plan  \
# 0         1               1
# 1         1               0
# 2         1               0
# 3         1               0
# 4         1               1
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...   891823180
# 1  {'favourite': {'is_favourite': False, '_links'...  ...    37303372
# 2  {'favourite': {'is_favourite': False, '_links'...  ...  2556937292
# 3  {'favourite': {'is_favourite': False, '_links'...  ...  3499653212
# 4  {'favourite': {'is_favourite': False, '_links'...  ...  1991259212
#
#   attractive_offer     price  \
# 0                0   8730000
# 1                0   9660000
# 2                0   3856000
# 3                0   8757000
# 4                0  11930000
#
#                                            price_czk  \
# 0  {'value_raw': 8730000, 'unit': '', 'name': 'Ce...
# 1  {'value_raw': 9660000, 'unit': '', 'name': 'Ce...
# 2  {'value_raw': 3856000, 'unit': '', 'name': 'Ce...
# 3  {'value_raw': 8757000, 'unit': '', 'name': 'Ce...
# 4  {'value_raw': 11930000, 'unit': '', 'name': 'C...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                      name  region_tip  \
# 0  Prodej bytu 1+kk 56 m²     2444139
# 1   Prodej bytu 3+1 95 m²           0
# 2  Prodej bytu 1+kk 34 m²           0
# 3  Prodej bytu 2+kk 59 m²           0
# 4  Prodej bytu 2+kk 88 m²           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.07162042763861, 'lon': 14.459427572...               False
# 1  {'lat': 50.118175427638604, 'lon': 14.49070557...               False
# 2  {'lat': 50.043525427638606, 'lon': 14.51326157...               False
# 3  {'lat': 50.074871427638605, 'lon': 14.49115157...               False
# 4  {'lat': 50.064315427638604, 'lon': 14.47253557...                True
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Task 2: Cleaning data
#
# ### 2a. Filter columns
# * filter only columns: `['locality', 'price', 'name', 'gps','hash_id','labelsAll','exclusively_at_rk']`
# * use `.copy()` to avoid `SettingWithCopyWarning` later

# %%
clean = raw[['locality', 'price', 'name', 'gps','hash_id','labelsAll','exclusively_at_rk']].copy()
clean.head()
# Out:
#                locality     price                    name  \
# 0      Praha 3 - Žižkov   8730000  Prodej bytu 1+kk 56 m²
# 1    Praha 8 - Kobylisy   9660000   Prodej bytu 3+1 95 m²
# 2  Praha 10 - Záběhlice   3856000  Prodej bytu 1+kk 34 m²
# 3      Praha 3 - Žižkov   8757000  Prodej bytu 2+kk 59 m²
# 4   Praha 3 - Vinohrady  11930000  Prodej bytu 2+kk 88 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.07162042763861, 'lon': 14.459427572...   891823180
# 1  {'lat': 50.118175427638604, 'lon': 14.49070557...    37303372
# 2  {'lat': 50.043525427638606, 'lon': 14.51326157...  2556937292
# 3  {'lat': 50.074871427638605, 'lon': 14.49115157...  3499653212
# 4  {'lat': 50.064315427638604, 'lon': 14.47253557...  1991259212
#
#                                            labelsAll  exclusively_at_rk
# 0  [[new_building, personal, balcony, cellar, ele...                  1
# 1  [[personal, after_reconstruction, loggia, pane...                  1
# 2  [[personal, panel, furnished], [playground, sm...                  0
# 3  [[new_building, personal, terrace, brick, cell...                  1
# 4  [[personal, balcony, brick], [candy_shop, vet,...                  1

# %% [markdown]
# ### 2b: GPS
# * Convert dictionary in `gps` column into two columns - `lat` and `lon`
# * use apply function on gps column
# * Note apply can return multiple columns

# %%
clean[['lat','lon']] = clean.gps.apply(lambda gps: pd.Series({'lat':gps['lat'], 'lon':gps['lon']}))

clean.head()
# Out:
#                locality     price                    name  \
# 0      Praha 3 - Žižkov   8730000  Prodej bytu 1+kk 56 m²
# 1    Praha 8 - Kobylisy   9660000   Prodej bytu 3+1 95 m²
# 2  Praha 10 - Záběhlice   3856000  Prodej bytu 1+kk 34 m²
# 3      Praha 3 - Žižkov   8757000  Prodej bytu 2+kk 59 m²
# 4   Praha 3 - Vinohrady  11930000  Prodej bytu 2+kk 88 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.07162042763861, 'lon': 14.459427572...   891823180
# 1  {'lat': 50.118175427638604, 'lon': 14.49070557...    37303372
# 2  {'lat': 50.043525427638606, 'lon': 14.51326157...  2556937292
# 3  {'lat': 50.074871427638605, 'lon': 14.49115157...  3499653212
# 4  {'lat': 50.064315427638604, 'lon': 14.47253557...  1991259212
#
#                                            labelsAll  exclusively_at_rk  \
# 0  [[new_building, personal, balcony, cellar, ele...                  1
# 1  [[personal, after_reconstruction, loggia, pane...                  1
# 2  [[personal, panel, furnished], [playground, sm...                  0
# 3  [[new_building, personal, terrace, brick, cell...                  1
# 4  [[personal, balcony, brick], [candy_shop, vet,...                  1
#
#          lat        lon
# 0  50.071620  14.459428
# 1  50.118175  14.490706
# 2  50.043525  14.513262
# 3  50.074871  14.491152
# 4  50.064315  14.472536

# %% [markdown]
# ### 2b. Get flat type from name
# * Name is always represented by string `Prodej bytu [type of flat] [Area] m^2`
# * try picking third word in string
# * check meaningfulness using `.value_counts()`

# %%
clean['flat_type'] = clean.name.apply(lambda nm: nm.split()[2])
clean
# Out:
#                 locality     price                            name  \
# 0       Praha 3 - Žižkov   8730000          Prodej bytu 1+kk 56 m²
# 1     Praha 8 - Kobylisy   9660000           Prodej bytu 3+1 95 m²
# 2   Praha 10 - Záběhlice   3856000          Prodej bytu 1+kk 34 m²
# 3       Praha 3 - Žižkov   8757000          Prodej bytu 2+kk 59 m²
# 4    Praha 3 - Vinohrady  11930000          Prodej bytu 2+kk 88 m²
# ..                   ...       ...                             ...
# 16     Praha 5 - Smíchov  23860000  Prodej bytu 2+kk 153 m² (Loft)
# 17      Praha 3 - Žižkov  10950000          Prodej bytu 2+kk 88 m²
# 18  Praha 1 - Nové Město  12123000          Prodej bytu 2+kk 67 m²
# 19     Praha 9 - Letňany  16753000         Prodej bytu 3+kk 116 m²
# 20     Praha 6 - Bubeneč  20623000         Prodej bytu 5+kk 199 m²
#
#                                                   gps     hash_id  \
# 0   {'lat': 50.07162042763861, 'lon': 14.459427572...   891823180
# 1   {'lat': 50.118175427638604, 'lon': 14.49070557...    37303372
# 2   {'lat': 50.043525427638606, 'lon': 14.51326157...  2556937292
# 3   {'lat': 50.074871427638605, 'lon': 14.49115157...  3499653212
# 4   {'lat': 50.064315427638604, 'lon': 14.47253557...  1991259212
# ..                                                ...         ...
# 16  {'lat': 50.06166042763861, 'lon': 14.410449572...  1242051660
# 17  {'lat': 50.06988942763861, 'lon': 14.479720572...  2047358028
# 18  {'lat': 50.07125442763861, 'lon': 14.443971572...  2584228940
# 19  {'lat': 50.119968427638604, 'lon': 14.51837357...   403190860
# 20  {'lat': 50.0871234276386, 'lon': 14.4151095723...  1745368140
#
#                                             labelsAll  exclusively_at_rk  \
# 0   [[new_building, personal, balcony, cellar, ele...                  1
# 1   [[personal, after_reconstruction, loggia, pane...                  1
# 2   [[personal, panel, furnished], [playground, sm...                  0
# 3   [[new_building, personal, terrace, brick, cell...                  1
# 4   [[personal, balcony, brick], [candy_shop, vet,...                  1
# ..                                                ...                ...
# 16  [[new_building, personal, balcony, loggia, ter...                  0
# 17  [[new_building, personal, cellar, elevator, pa...                  0
# 18  [[personal, brick, cellar, elevator, furnished...                  0
# 19  [[new_building, personal, balcony, loggia, ter...                  0
# 20  [[personal, balcony, loggia, terrace, brick, c...                  0
#
#           lat        lon flat_type
# 0   50.071620  14.459428      1+kk
# 1   50.118175  14.490706       3+1
# 2   50.043525  14.513262      1+kk
# 3   50.074871  14.491152      2+kk
# 4   50.064315  14.472536      2+kk
# ..        ...        ...       ...
# 16  50.061660  14.410450      2+kk
# 17  50.069889  14.479721      2+kk
# 18  50.071254  14.443972      2+kk
# 19  50.119968  14.518374      3+kk
# 20  50.087123  14.415110      5+kk
#
# [105 rows x 10 columns]

# %% [markdown]
# ### 2c. Get area from name
# * Naive: select the word before last word
# * Then try navigating using the index of `'m²'`
# * if this also fail, then you will need to use regex

# %%
def name_to_area(nm):
    splitted= nm.split()
    
    m2_idx = splitted.index('m²')
    
    return int(splitted[m2_idx-1])

clean['area'] = clean.name.apply(name_to_area)
clean
# Out:
#                 locality     price                            name  \
# 0       Praha 3 - Žižkov   8730000          Prodej bytu 1+kk 56 m²
# 1     Praha 8 - Kobylisy   9660000           Prodej bytu 3+1 95 m²
# 2   Praha 10 - Záběhlice   3856000          Prodej bytu 1+kk 34 m²
# 3       Praha 3 - Žižkov   8757000          Prodej bytu 2+kk 59 m²
# 4    Praha 3 - Vinohrady  11930000          Prodej bytu 2+kk 88 m²
# ..                   ...       ...                             ...
# 16     Praha 5 - Smíchov  23860000  Prodej bytu 2+kk 153 m² (Loft)
# 17      Praha 3 - Žižkov  10950000          Prodej bytu 2+kk 88 m²
# 18  Praha 1 - Nové Město  12123000          Prodej bytu 2+kk 67 m²
# 19     Praha 9 - Letňany  16753000         Prodej bytu 3+kk 116 m²
# 20     Praha 6 - Bubeneč  20623000         Prodej bytu 5+kk 199 m²
#
#                                                   gps     hash_id  \
# 0   {'lat': 50.07162042763861, 'lon': 14.459427572...   891823180
# 1   {'lat': 50.118175427638604, 'lon': 14.49070557...    37303372
# 2   {'lat': 50.043525427638606, 'lon': 14.51326157...  2556937292
# 3   {'lat': 50.074871427638605, 'lon': 14.49115157...  3499653212
# 4   {'lat': 50.064315427638604, 'lon': 14.47253557...  1991259212
# ..                                                ...         ...
# 16  {'lat': 50.06166042763861, 'lon': 14.410449572...  1242051660
# 17  {'lat': 50.06988942763861, 'lon': 14.479720572...  2047358028
# 18  {'lat': 50.07125442763861, 'lon': 14.443971572...  2584228940
# 19  {'lat': 50.119968427638604, 'lon': 14.51837357...   403190860
# 20  {'lat': 50.0871234276386, 'lon': 14.4151095723...  1745368140
#
#                                             labelsAll  exclusively_at_rk  \
# 0   [[new_building, personal, balcony, cellar, ele...                  1
# 1   [[personal, after_reconstruction, loggia, pane...                  1
# 2   [[personal, panel, furnished], [playground, sm...                  0
# 3   [[new_building, personal, terrace, brick, cell...                  1
# 4   [[personal, balcony, brick], [candy_shop, vet,...                  1
# ..                                                ...                ...
# 16  [[new_building, personal, balcony, loggia, ter...                  0
# 17  [[new_building, personal, cellar, elevator, pa...                  0
# 18  [[personal, brick, cellar, elevator, furnished...                  0
# 19  [[new_building, personal, balcony, loggia, ter...                  0
# 20  [[personal, balcony, loggia, terrace, brick, c...                  0
#
#           lat        lon flat_type  area
# 0   50.071620  14.459428      1+kk    56
# 1   50.118175  14.490706       3+1    95
# 2   50.043525  14.513262      1+kk    34
# 3   50.074871  14.491152      2+kk    59
# 4   50.064315  14.472536      2+kk    88
# ..        ...        ...       ...   ...
# 16  50.061660  14.410450      2+kk   153
# 17  50.069889  14.479721      2+kk    88
# 18  50.071254  14.443972      2+kk    67
# 19  50.119968  14.518374      3+kk   116
# 20  50.087123  14.415110      5+kk   199
#
# [105 rows x 11 columns]

# %% [markdown]
# ## Task 3 (Homework): Convert column`labelsAll` into boolean variables
#
# ### Task 3a. Get all possible label names
# * deal with nested-list structure
# * Hint: try sum the whole column to get a nested list of lists.
# * Then flatten the nested list (2D to 1D)
# * Finally keep only unique elements

# %%
possible_labels = list(set([item for sublist in raw.labelsAll.sum() for item in sublist]))
possible_labels
# Out:
# ['after_reconstruction',
#  'new_building',
#  'cellar',
#  'candy_shop',
#  'sports',
#  'drugstore',
#  'collective',
#  'elevator',
#  'playground',
#  'kindergarten',
#  'metro',
#  'loggia',
#  'sightseeing',
#  'movies',
#  'school',
#  'balcony',
#  'in_construction',
#  'brick',
#  'natural_attraction',
#  'not_furnished',
#  'bus_public_transport',
#  'small_shop',
#  'restaurant',
#  'panel',
#  'tavern',
#  'post_office',
#  'vet',
#  'atm',
#  'garage',
#  'furnished',
#  'terrace',
#  'shop',
#  'partly_furnished',
#  'medic',
#  'theater',
#  'parking_lots',
#  'train',
#  'tram',
#  'personal']

# %% [markdown]
# ### 4b. Test existence of label `cellar` for offers
# * again deal with nested list of list structure
# * write generic function `test_existence_of_label(offer_labels,label)`

# %%
def test_existence_of_label(offer_labels,label):
    return label in [item for sublist in offer_labels for item in sublist]
raw.labelsAll.apply(lambda offer_labels: test_existence_of_label(offer_labels, 'cellar'))
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# Name: labelsAll, Length: 105, dtype: bool

# %% [markdown]
# ### 4c. Test existence of all possible labels
# * use apply returning series with all labels

# %%
def existence_of_all_labels(offer_labels, possible_labels):
    return pd.Series({
        label:test_existence_of_label(offer_labels,label)
        for label in possible_labels
    })

raw.labelsAll.apply(lambda offer_labels: existence_of_all_labels(offer_labels, possible_labels))
# Out:
#     after_reconstruction  new_building  cellar  candy_shop  sports  drugstore  \
# 0                  False          True    True        True    True       True
# 1                   True         False   False        True    True       True
# 2                  False         False   False        True    True       True
# 3                  False          True    True        True    True       True
# 4                  False         False   False        True    True       True
# ..                   ...           ...     ...         ...     ...        ...
# 16                 False          True    True        True    True       True
# 17                 False          True    True        True    True       True
# 18                 False         False    True        True    True       True
# 19                 False          True    True        True    True       True
# 20                 False         False    True        True    True       True
#
#     collective  elevator  playground  kindergarten  ...  furnished  terrace  \
# 0        False      True        True          True  ...      False    False
# 1        False      True        True          True  ...       True    False
# 2        False     False        True          True  ...       True    False
# 3        False     False        True          True  ...       True     True
# 4        False     False        True          True  ...      False    False
# ..         ...       ...         ...           ...  ...        ...      ...
# 16       False      True        True          True  ...       True     True
# 17       False      True        True          True  ...       True    False
# 18       False      True        True          True  ...       True    False
# 19       False      True        True          True  ...       True     True
# 20       False      True        True          True  ...      False     True
#
#     shop  partly_furnished  medic  theater  parking_lots  train  tram  \
# 0   True             False   True     True          True   True  True
# 1   True             False   True     True         False   True  True
# 2   True             False   True     True         False   True  True
# 3   True             False   True     True         False   True  True
# 4   True             False   True     True         False   True  True
# ..   ...               ...    ...      ...           ...    ...   ...
# 16  True             False   True     True          True   True  True
# 17  True             False   True     True          True   True  True
# 18  True             False   True     True         False   True  True
# 19  True             False   True     True          True   True  True
# 20  True              True   True     True         False   True  True
#
#     personal
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ..       ...
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
#
# [105 rows x 39 columns]
